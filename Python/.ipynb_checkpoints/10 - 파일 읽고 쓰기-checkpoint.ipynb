# %% [markdown]
# <center><img src='https://raw.githubusercontent.com/Jangrae/img/master/title.png' width=500/></center>

# %% [markdown]
# # 10.파일 읽고 쓰기
#
# - 텍스트 파일을 읽고 쓰는 기본적인 방법을 학습합니다.
# - 좋은 글을 읽어와 멋진 워드 클라우드를 만들어봅니다
# - 파일을 다루는 상세한 기술이 필요한 경우 관련 자료를 찾아 학습하기를 권고합니다.

# %% [markdown]
# ## 10.1.경로 확인
#
# - 사용자마다 파일을 저장하고 읽는 기본 경로를 ‘홈 디렉터리‘ 라고 합니다.
# - pathlib 패키지의 Path.home() 함수로 사용자 홈 디렉터리를 확인합니다.

# %%
# 홈 디렉터리 확인
from pathlib import Path

print(Path.home())
# Out:
# C:\Users\User

# %% [markdown]
# - pathlib 패키지의 Path.cwd() 함수로 현재 작업 디렉터리를 확인합니다.

# %%
# 작업 디렉터리 확인
from pathlib import Path

print(Path.cwd())
# Out:
# C:\Users\User\Python

# %% [markdown]
# - Path.cwd().glob()를 사용해 디렉터리 안의 내용을 확인합니다.

# %%
# 디렉터리 내용 확인
from pathlib import Path

files = Path.cwd().glob('*')

for f in files:
     print(f)
# Out:
# C:\Users\User\Python\.ipynb_checkpoints
# C:\Users\User\Python\01 - 연산자와 기본 자료형.ipynb
# C:\Users\User\Python\02 - 문자열 자료형.ipynb
# C:\Users\User\Python\03 - 리스트.ipynb
# C:\Users\User\Python\04 - 튜플.ipynb
# C:\Users\User\Python\05 - 집합.ipynb
# C:\Users\User\Python\06 - 딕셔너리.ipynb
# C:\Users\User\Python\07 - 제어문.ipynb
# C:\Users\User\Python\08 - 함수.ipynb
# C:\Users\User\Python\09 - 정규 표현식.ipynb
# C:\Users\User\Python\10 - 파일 읽고 쓰기.ipynb
# C:\Users\User\Python\11 - 엑셀 파일 다루기.ipynb
# C:\Users\User\Python\12 - 이메일 보내기.ipynb
# C:\Users\User\Python\Animal.xlsx
# C:\Users\User\Python\Dream.txt
# C:\Users\User\Python\DX_데이터 다루기_실습자료.zip
# C:\Users\User\Python\Fruit.xlsx
# C:\Users\User\Python\human.jpg
# C:\Users\User\Python\LittleStar.txt
# C:\Users\User\Python\Members.xlsx
# C:\Users\User\Python\MyFile.txt
# C:\Users\User\Python\Poem.txt
# C:\Users\User\Python\Untitled.ipynb
# C:\Users\User\Python\리뷰0226.ipynb
# C:\Users\User\Python\실습01 - 연산자와 기본 자료형.ipynb
# C:\Users\User\Python\실습02 - 문자열 자료형.ipynb
# C:\Users\User\Python\실습03 - 리스트.ipynb
# C:\Users\User\Python\실습04 - 딕셔너리.ipynb
# C:\Users\User\Python\실습05 - 제어문.ipynb
# C:\Users\User\Python\실습06 - 함수.ipynb
# C:\Users\User\Python\실습07 - 파일 읽고 쓰기.ipynb
# C:\Users\User\Python\실습08 - 엑셀 파일 다루기.ipynb
# C:\Users\User\Python\실습09 - 이메일 보내기.ipynb
# C:\Users\User\Python\연습01.ipynb

# %% [markdown]
# ## 10.2.기본적인 파일 읽고 쓰기

# %% [markdown]
# **1) 파일 쓰기**
#
# - **w** 모드로 파일을 열어 **write()** 메서드로 파일에 기록합니다.
# - 이미 같은 이름의 파일이 있다면 제거되고 새 파일이 만들어집니다.
# - 경로를 지정하지 않으면 현재 작업 디렉터리에 기록됩니다.

# %%
# 파일 열기
f = open('MyFile.txt', 'w') # 파일이 없으면 생성

# 파일 쓰기
f.write('안녕하세요?\n')

# 파일 닫기
f.close()

# %%
with open('MyFile.txt', 'w') as f:
    f.write('안녕하세요?\n')  # close 필요 없음

# %% [markdown]
# - mkdir()를 사용해 현재 작업 디렉터리에 새로운 디렉터리를 만듭니다.
# - exist_ok=True를 지정하면 이미 폴더가 있는 경우 해당 폴더를 사용합니다.

# %%
# 디렉터리 만들기
Path('Files').mkdir(exist_ok=True)

# %% [markdown]
# - Files/MyFile.txt 처럼 경로를 지정해 특정 디렉터리 안에 파일을 만듭니다.
# - Windows에서 경로 구분자로 '\\' 를 사용하는 것과 달리 '/' 를 사용함에 주의합니다.

# %%
# 파일 열기
f = open('Files/MyFile.txt', 'w')

# 파일 쓰기
f.write('모두들 안녕하세요?\n')

# 파일 닫기
f.close()

# %% [markdown]
# **2) 파일 읽기**
#
# - r 모드로 파일을 열어 read() 메서드로 파일을 읽을 수 있습니다.
# - 지정한 파일이 없으면 오류가 발생합니다.

# %%
# 파일 열기
f = open('MyFile.txt', 'r')

# 내용 읽기
print(f.read())

# 파일 닫기
f.close()
# Out:
# 안녕하세요?

# %%
with open('MyFile.txt', 'r') as f:
    print(f.read())
# Out:
# 안녕하세요?

# %% [markdown]
# - 경로를 지정해 특정 디렉터리 안의 파일을 읽어옵니다.

# %%
# 파일 열기
f = open('Files/MyFile.txt', 'r')

# 내용 읽기
print(f.read())

# 파일 닫기
f.close()
# Out:
# 모두들 안녕하세요?

# %%
with open('Files/MyFile.txt', 'r') as f:
    print(f.read())
# Out:
# 모두들 안녕하세요?

# %% [markdown]
# **3) 파일 내용 추가**
#
# - a 모드로 파일을 열어 write() 메서드로 내용을 추가할 수 있습니다.
# - 지정한 파일이 없으면 새 파일이 만들어집니다.

# %%
# 파일 열기
f = open('MyFile.txt', 'a')

# 내용 추가
f.write('만나서 반갑습니다!')

# 파일 닫기
f.close()

# %% [markdown]
# - 추가된 내용을 확인합니다.

# %%
# 파일 열기
f = open('MyFile.txt', 'r')
print(f.read())
f.close()
# Out:
# 안녕하세요?
# 만나서 반갑습니다!

# %% [markdown]
# **4) 파일 있으면 오류 발생**
#
# - x 모드로 파일을 열면 같은 파일이 있는 경우 오류를 발생시킵니다.
# - 파일이 없으면 w 모드로 파일은 연 결과가 됩니다.

# %%
# 파일 열기
f = open('MyFile.txt', 'x') # x 모드 파일 있으면 오류 없으면 생성

# 내용 쓰기
f.write('만나서 반갑습니다!')

# 파일 닫기
f.close()
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[19], line 2
#       1 # 파일 열기
# ----> 2 f = open('MyFile.txt', 'x') # x 모드 파일 있으면 오류 없으면 생성
#       4 # 내용 쓰기
#       5 f.write('만나서 반갑습니다!')
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:286, in _modified_open(file, *args, **kwargs)
#     279 if file in {0, 1, 2}:
#     280     raise ValueError(
#     281         f"IPython won't let you open fd={file} by default "
#     282         "as it is likely to crash IPython. If you know what you are doing, "
#     283         "you can use builtins' open."
#     284     )
# --> 286 return io_open(file, *args, **kwargs)
#
# FileExistsError: [Errno 17] File exists: 'MyFile.txt'

# %% [markdown]
# - 같은 이름의 파일이 있어 오류가 나는 것에 대한 핸들링을 합니다.

# %%
# 오류 핸들링
try:
    f = open('MyFile.txt', 'x')
    f.write('만나서 반갑습니다!')
    f.close()
except FileExistsError:     #  이미 파일이 있으면
    print('같은 이름의 파일이 있습니다.')
else:                       # 그렇지 않으면
    print('파일 쓰기 성공했습니다.')
finally:                    # 마무리
    print('수고하셨습니다.')
# Out:
# 같은 이름의 파일이 있습니다.
# 수고하셨습니다.

# %% [markdown]
# <img src='https://raw.githubusercontent.com/jangrae/img/master/practice_01.png' width=120 align = "left"/>

# %% [markdown]
# [문1] Python.txt 파일을 만드세요.

# %%
# 파일 열기
f = open('Python.txt', 'w')

# %% [markdown]
# [문2] 아래 내용을 파일에 입력해 보세요.
#
# - 홍길동 대신 자신의 이름을 입력합니다.
# - 입력 후에는 파일을 close 하고, 탐색기에서 열어 보세요.
#
# <파이썬과 나>
# 시인: 홍길동

# %%
# 내용 쓰기
f.write('''<파이썬과 나>
시인: 홍길동''')

# 파일 닫기
f.close()

# %% [markdown]
# [문3] 아래 내용을 파일에 추가해 봅시다.
#
# - 추가한 후에는 파일을 close 하고, 탐색기에서 열어 보세요.
#
# ~~~
# 어느날
# 파이썬이 나에게 왔다.
# 많이 낯설었다.
# 지금은 나와 하나가 되었다.
# 파이썬이 나고,
# 내가 파이썬이다.
# ~~~

# %%
# 파일 열기
f = open('Python.txt', 'a')

# 내용 추가
f.write('''
어느날
파이썬이 나에게 왔다.
많이 낯설었다.
지금은 나와 하나가 되었다.
파이썬이 나고,
내가 파이썬이다.''')

# 파일 닫기
f.close()

# %% [markdown]
# ## 10.3.파일을 다루는 편리한 메서드

# %% [markdown]
# **1) writelines() 메서드**
#
# - writelines() 메서드를 사용해 행 리스트를 파일에 기록할 수 있습니다.

# %%
# 파일 여러 줄 쓰기
hello = ['안녕하세요?\n', '만나서 반갑습니다!\n', '우리 사이좋게 잘 지내요.\n']
f = open('MyFile.txt', 'w')
f.writelines(hello)
f.close()

# %% [markdown]
# - 추가된 내용을 확인합니다.

# %%
# 파일 읽기
f =  open('MyFile.txt', 'r')
print(f.read())
f.close()
# Out:
# 안녕하세요?
# 만나서 반갑습니다!
# 우리 사이좋게 잘 지내요.

# %% [markdown]
# **2) readlines() 메서드**
#
# - readlines() 메서드를 사용해 모든 행을 한 번에 읽을 수 있습니다.
# - 결과는 리스트가 되므로, 반복문으로 한 행 씩 읽을 수 있습니다.

# %%
# 파일 한 번에 읽기
f = open('MyFile.txt', 'r')
result = f.readlines()
f.close()

# 내용 확인
print(result)
# Out:
# ['안녕하세요?\n', '만나서 반갑습니다!\n', '우리 사이좋게 잘 지내요.\n']

# %%
# 반복문으로 한 행씩 표시
for txt in result:
    print(txt, end='')
# Out:
# 안녕하세요?
# 만나서 반갑습니다!
# 우리 사이좋게 잘 지내요.

# %% [markdown]
# **3) readline() 메서드**
#
# - readline() 메서드를 사용해 행 단위로 읽을 수 있습니다.
# - 결과는 문자열이 됩니다.

# %%
# 파일 읽기
f = open('MyFile.txt', 'r')

# 내용 읽기
print(f.readline())
print(f.readline())
print(f.readline())

# 파일 닫기
f.close()
# Out:
# 안녕하세요?
#
# 만나서 반갑습니다!
#
# 우리 사이좋게 잘 지내요.

# %% [markdown]
# - 반복문을 이용해 모든 행을 읽어올 수 있습니다.

# %%
# 파일 읽기
f = open('MyFile.txt', 'r')
result = f.readline()

# 반복문으로 한 행씩 읽어 표시
while result:
    print(result, end='')
    result = f.readline()

# 파일 닫기
f.close()
# Out:
# 안녕하세요?
# 만나서 반갑습니다!
# 우리 사이좋게 잘 지내요.

# %% [markdown]
# ## 10.4.워드 클라우드 만들기
#
# - 마틴루터킹 목사의 'I have a Dream' 연설문을 가지고 워드 클라우드를 만들어 봅니다.

# %% [markdown]
# <img src='https://i.ytimg.com/vi/mrP2lh7oTBU/maxresdefault.jpg' width=650 align = "left"/>

# %% [markdown]
# - 워드 클라우드를 만드는 순서는 다음과 같습니다.
#
# (1) 텍스트파일로 저장하기
#
# - 읽을 파일을 만듭니다.
# - 여기서는 수동으로 어디선가 가져오겠지만,
# - 나중에는 크롤링을 통해서 웹에서 가져올 수도 있습니다.
#
#
# (2) 텍스트 전처리
#
# - 파일을 읽어서 split() 메서드를 사용해 단어 단위로 쪼갭니다.
# - 단어별 빈도수를 계산하여 딕셔너리 형태로 저장합니다.
# - 분석에 의미가 없는 조사들은 제거합니다.
#
# (3) 워드 클라우드 그리기
#
# -  wordcloud 라이브러리를 설치한 후 불러옵니다.
# - 워드 클라우드를 그립니다.

# %% [markdown]
# **1) 텍스트파일로 저장하기**
#
# - 수업을 위해 이미 저장해 놓았습니다.

# %% [markdown]
# **2) 텍스트 전처리**
#
# - 우선 파일을 읽어와 내용을 확인합니다.
# - 한글 파일을 읽어올 때 인코딩 오류가 발생하면 encoding='CP949'로 지정합니다.

# %%
# 파일 읽기
file = open('Dream.txt', 'r', encoding='UTF-8')
text = file.read()
file.close()

# 확인(100 글자만)
text[:100]
# Out:
# 'I am happy to join with you today in what will go down in history as the greatest demonstration for '

# %% [markdown]
# - split() 메서드를 사용해  단어 단위로 잘라 리스트 형태로 만듭니다.

# %%
# 공백을 구분자로 하여 단어 단위로 자르기
wordList = text.split()

# 확인(10 개만)
wordList[:10]
# Out:
# ['I', 'am', 'happy', 'to', 'join', 'with', 'you', 'today', 'in', 'what']

# %% [markdown]
# - 단어별 빈도수를 계산하여 딕셔너리로 저장합니다.

# %%
# 중복 단어 제거
worduniq = set(wordList)

# 딕셔너리 선언
wordCount = {}

# 단어별 개수 저장
for w in worduniq:
    wordCount[w] = wordList.count(w)

# 제외 대상 조사
del_word = ['the','a','is','are', 'not','of','on','that','this','and','be','to', 'from']

# 제외하기
for w in del_word:
    if w in wordCount:
        del wordCount[w]
        
# 확인
print(wordCount)
# Out:
# {'militancy': 1, 'still': 4, 'obligation,': 1, 'land': 2, 'Lord': 1, 'straight,': 1, 'today.': 2, 'discords': 1, 'able': 8, 'free.': 1, 'have': 19, 'himself': 1, 'sixty-three': 1, 'rights.': 1, 'dream': 9, 'has': 5, 'black': 3, 'wrongful': 1, 'brothers,': 1, 'men': 3, 'former': 2, 'hope': 2, 'American,': 1, 'came': 2, 'Protestants': 1, 'been': 2, 'quest': 1, 'rights': 1, 'lead': 1, 'righteousness': 1, 'little': 2, 'I': 18, 'they': 2, 'honoring': 1, 'valley': 3, '—': 1, 'usual.': 1, 'rock': 1, 'there': 3, 'gain': 1, 'pass': 1, 'Georgia': 1, 'city,': 1, 'God': 1, 'drinking': 1, 'returns': 1, 'Constitution': 1, 'threshold': 1, 'seek': 1, 'forever': 1, 'police': 1, 'marvelous': 1, 'together': 2, 'God’s': 3, 'were': 1, 'defaulted': 1, 'free': 3, 'stand': 3, 'tied': 1, 'magnificent': 1, 'today': 3, 'fall': 1, 'deeply': 1, 'autumn': 1, 'faith': 5, 'slums': 1, 'never': 2, 'heat': 1, 'friends,': 1, 'when': 3, 'knowing': 2, 'life,': 1, '“When': 1, 'battered': 1, 'ring.”': 1, 'at': 4, 'racial': 2, 'We': 9, 'cooling': 1, 'deeds.': 1, 'architects': 1, 'cannot': 5, 'smaller': 1, 'your': 1, 'place': 1, 'march': 1, 'hallowed': 1, 'last!”': 1, 'rightful': 1, 'table': 1, 'hills': 1, 'will': 27, 'gradualism.': 1, 'Pennsylvania!': 1, 'bank': 1, 'take': 1, 'devotees': 1, 'signing': 1, 'difficulties': 1, 'fresh': 1, 'Negro': 12, 'left': 1, 'dignity': 1, 'exalted,': 1, 'business': 1, 'granted': 1, 'northern': 1, 'tranquility': 1, 'up': 4, 'lift': 1, 'fatigue': 1, 'creed:': 1, 'insufficient': 1, 'pursuit': 1, 'awakening': 1, 'words': 3, 'like': 2, 'boys': 2, 'Let': 8, 'situation': 2, 'brothers.': 1, 'old': 1, 'presence': 1, 'whirlwinds': 1, 'despair': 1, 'vast': 1, 'But': 4, 'gaining': 1, 'satisfied,': 1, 'King': 2, 'ago,': 1, 'rolls': 1, 'suffering': 1, 'these': 1, 'sing.': 1, 'prodigious': 1, 'hope.': 2, 'walk,': 1, 'realize': 1, 'nation.': 2, 'withering': 1, 'those': 1, 'hotels': 1, 'no': 1, 'beacon': 1, 'force': 1, 'basic': 1, 'life': 1, 'corners': 1, 'happiness.': 1, 'pledge': 1, 'beginning.': 1, 'Nineteen': 1, 'made': 3, 'go': 6, 'satisfy': 1, 'great': 5, 'violence.': 1, 'bound': 1, 'languishing': 1, 'heightening': 1, 'underestimate': 1, 'Georgia,': 1, 'asking': 1, 'walk': 2, 'exile': 1, 'Again': 1, 'Mississippi,': 2, 'sing': 2, 'sweet': 1, 'Rockies': 1, 'interposition': 1, 'promise': 1, 'had': 1, 'heir.': 1, 'self-evident:': 1, 'equal.”': 1, 'plane': 1, 'crippled': 1, 'narrow': 1, 'satisfied?”': 1, 'discontent': 1, 'conduct': 1, 'slaves': 2, 'storms': 1, 'lonely': 1, 'off': 2, 'evidenced': 1, 'engulfed': 1, 'tribulations.': 1, 'ghetto': 1, 'allow': 1, 'condition.': 1, 'his': 2, 'ring.': 1, 'momentous': 1, 'suffering.': 1, 'later,': 4, 'hold': 1, 'now': 1, 'with': 10, 'luxury': 1, 'Martin': 2, 'shadow': 1, 'remind': 1, 'jangling': 1, 'check.': 1, 'promissory': 2, 'even': 1, 'turn': 1, 'state': 3, 'village': 1, 'sacred': 1, 'larger': 1, 'sisters': 1, 'physical': 2, 'heavy': 1, 'until': 4, 'Jr': 1, '“insufficient': 1, 'fierce': 1, 'its': 1, 'spot': 1, 'also': 1, 'created': 1, 'desolate': 1, 'moment': 1, 'York.': 1, 'glory': 1, 'somehow': 1, 'given': 1, 'rude': 1, 'meeting': 1, 'nation': 8, 'blow': 1, 'where': 4, 'happy': 1, 'Have': 3, 'note': 3, 'bankrupt.': 1, 'skin': 1, 'needed': 1, 'white': 5, 'years': 5, 'South.': 1, 'oppression,': 1, 'in': 19, 'red': 1, 'Those': 1, 'mountains': 1, 'One': 3, 'tragic': 1, 'concerned.': 1, 'long': 4, 'marked': 1, 'redemptive.': 1, 'time': 4, 'nation’s': 1, 'character.': 1, 'nullification,': 1, 'bitterness': 1, 'invigorating': 1, 'alone.': 1, 'tranquilizing': 1, 'hatred.': 1, 'night': 1, 'ring,': 1, 'people': 2, 'Lookout': 1, 'judged': 1, 'shake': 1, 'must': 9, 'say': 2, 'by': 8, 'majestic': 1, 'vote.': 1, 'distrust': 1, 'crooked': 1, 'shall': 5, 'sweltering': 2, '“We': 1, 'freedom': 19, 'cup': 1, 'ghettos': 1, 'desert': 1, 'discrimination.': 1, 'citizenship': 1, 'struggle': 2, 'moment,': 1, 'thee,': 1, 'people,': 1, 'snowcapped': 1, 'four': 1, 'thank': 1, 'prosperity.': 1, 'island': 1, 'drug': 1, 'captivity.':  ...

# %% [markdown]
# **3) 워드 클라우드 그리기**
#
# - wordcloud 패키지를 설치합니다.

# %%
# 패키지 설치합
# !pip install wordcloud
# Out:
# Collecting wordcloud
#   Obtaining dependency information for wordcloud from https://files.pythonhosted.org/packages/f5/b0/247159f61c5d5d6647171bef84430b7efad4db504f0229674024f3a4f7f2/wordcloud-1.9.3-cp311-cp311-win_amd64.whl.metadata
#   Downloading wordcloud-1.9.3-cp311-cp311-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\user\anaconda3\lib\site-packages (from wordcloud) (1.24.3)
# Requirement already satisfied: pillow in c:\users\user\anaconda3\lib\site-packages (from wordcloud) (10.0.1)
# Requirement already satisfied: matplotlib in c:\users\user\anaconda3\lib\site-packages (from wordcloud) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Downloading wordcloud-1.9.3-cp311-cp311-win_amd64.whl (300 kB)
#    ---------------------------------------- 0.0/300.2 kB ? eta -:--:--
#    ---- ----------------------------------- 30.7/300.2 kB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 300.2/300.2 kB 4.6 MB/s eta 0:00:00
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.3

# %% [markdown]
# - 드디어! 워드 클라우드를 그립니다.

# %%
# 라이브러리 불러오기
import matplotlib.pyplot as plt
from wordcloud import WordCloud
# %config InlineBackend.figure_format='retina'

# 워드 클라우드 만들기
wordcloud = WordCloud(font_path = 'C:/Windows/fonts/HMKMRHD.TTF',  # 글꼴
                      width=2000,  # 너비
                      height=1000, # 높이
                      background_color='white').generate_from_frequencies(wordCount) 

# 표시하기
plt.figure(figsize=(12, 6))
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# <img src='https://raw.githubusercontent.com/jangrae/img/master/practice_01.png' width=120 align="left"/>

# %% [markdown]
# [문1] 불필요한 조사나 단어를 좀 더 제외한 후 다시 그려봅니다.

# %%
# 제외 대상 조사
del_word = ['as', 'by', 'ring', 'was', 'an', 'it', 'can']

# 제외하기
for w in del_word:
    if w in wordCount:
        del wordCount[w]

# %%
# 워드 클라우드 그리기
# %config InlineBackend.figure_format='retina'

# 워드 클라우드 만들기
wordcloud = WordCloud(font_path = 'C:/Windows/fonts/HMKMRHD.TTF',  # 글꼴
                      width=2000,  # 너비
                      height=1000, # 높이
                      background_color='white').generate_from_frequencies(wordCount) 

# 표시하기
plt.figure(figsize=(12, 6))
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# ## 참고: 이미지 파일 사용
#
# - 이미지 파일을 사용해 워드클라우드 전체 프레임 모양을 변경할 수 있습니다.

# %%
# 라이브러리 불러오기
import numpy as np
from PIL import Image

# 이미지 불러오기
masking_image = np.array(Image.open('human.jpg'))

# 워드 클라우드 만들기
wordcloud = WordCloud(font_path = 'C:/Windows/fonts/HMKMRHD.TTF',
                      width=2000,
                      height=1000,
                      mask=masking_image,
                      background_color='white').generate_from_frequencies(wordCount)

# 표시하기
plt.figure(figsize=(12, 6))
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()
