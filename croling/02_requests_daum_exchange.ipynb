# %% [markdown]
# ### Daum Exchange
# - `https://finance.daum.net`

# %%
import pandas as pd
import requests

# %%
# 1. URL
url = 'https://finance.daum.net/api/exchanges/summaries' # 다음 환율

# %%
# Cookie, Referer, User-Agent에서 결정 남 # 403이 나올 때 
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36',
          'Referer': 'https://finance.daum.net/exchanges',}

# %%
# 2. request -> response
response = requests.get(url, headers=headers)
response
# Out:
# <Response [200]>

# %%
response.text[:500]
# Out:
# '{"data":[{"symbolCode":"FRX.KRWUSD","date":"2024-03-19 10:12:06","currencyCode":"USD","currencyName":"달러","currencyUnit":1,"country":"미국","region":{"korName":"아메리카","engName":"America"},"name":"미국 (USD/KRW)","recurrenceCount":47,"basePrice":1338.1,"change":"RISE","changePrice":1.6,"changeRate":0.0011971568,"cashBuyingPrice":1361.51,"cashSellingPrice":1314.69,"ttBuyingPrice":1325.0,"ttSellingPrice":1351.2,"tcBuyingPrice":null,"fcSellingPrice":null,"exchangeCommission":7.1788,"usDollarRate":1.0,"c'

# %%
# 3. parsing : json(str) -> DataFrame
data = response.json()['data']
df = pd.DataFrame(data)[['symbolCode', 'currencyCode', 'currencyName', 'basePrice']]

# %%
df
# Out:
#     symbolCode currencyCode currencyName  basePrice
# 0   FRX.KRWUSD          USD           달러    1338.10
# 1   FRX.KRWJPY          JPY            엔     896.16
# 2   FRX.KRWCNY          CNY           위안     185.66
# 3   FRX.KRWEUR          EUR           유로    1454.65
# 4   FRX.KRWGBP          GBP          파운드    1702.06
# 5   FRX.KRWCHF          CHF           프랑    1506.19
# 6   FRX.KRWCAD          CAD           달러     987.93
# 7   FRX.KRWNZD          NZD           달러     812.70
# 8   FRX.KRWHKD          HKD           달러     171.10
# 9   FRX.KRWBRL          BRL           레알     265.98
# 10  FRX.KRWMXN          MXN           페소      79.46
# 11  FRX.KRWAED          AED          디르함     364.35
# 12  FRX.KRWKWD          KWD          디나르    4353.53
# 13  FRX.KRWBHD          BHD          디나르    3552.16
# 14  FRX.KRWINR          INR           루피      16.13
# 15  FRX.KRWSAR          SAR           리얄     356.80
# 16  FRX.KRWNOK          NOK          크로네     125.51
# 17  FRX.KRWDKK          DKK          크로나     195.07
# 18  FRX.KRWMYR          MYR          링키트     283.26
# 19  FRX.KRWBDT          BDT           타카      12.19
# 20  FRX.KRWPKR          PKR           루피       4.80
# 21  FRX.KRWIDR          IDR          루피아       8.55
# 22  FRX.KRWTWD          TWD           달러      42.20
# 23  FRX.KRWPHP          PHP           페소      24.03
# 24  FRX.KRWSEK          SEK          크로나     128.18
# 25  FRX.KRWAUD          AUD           달러     876.32
# 26  FRX.KRWSGD          SGD           달러     998.99
# 27  FRX.KRWTHB          THB           바트      37.15
# 28  FRX.KRWEGP          EGP          파운드      28.40
# 29  FRX.KRWBND          BND           달러     998.99
# 30  FRX.KRWILS          ILS          쉐캐림     366.33
# 31  FRX.KRWJOD          JOD          디나르    1887.31
# 32  FRX.KRWVND          VND            동       5.41
# 33  FRX.KRWRUB          RUB           루블      14.59
# 34  FRX.KRWHUF          HUF          포린트       3.68
# 35  FRX.KRWPLN          PLN          줄러티     336.51
# 36  FRX.KRWZAR          ZAR           랜드      70.58
# 37  FRX.KRWMNT          MNT          투그릭       0.39
# 38  FRX.KRWCZK          CZK          코루나      57.65
# 39  FRX.KRWKZT          KZT           텡게       2.97
# 40  FRX.KRWQAR          QAR           리얄     366.90
# 41  FRX.KRWTRY          TRY           리라      41.38
